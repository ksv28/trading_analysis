# %%
pip install numpy scipy pandas openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------  12.3/12.4 MB 73.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 63.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ------------------------- -------------- 23.3/37.3 MB 108.3 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 97.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 9.9/9.9 MB 125.1 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
# ...

# %%
import pandas as pd
import numpy as np

# %%
market = pd.read_excel("prices_round_1_day_0.xlsx")
trades = pd.read_csv("trades_round_1_day_0.csv")

print("Market data shape:", market.shape)
print("Trades data shape:", trades.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 market = pd.read_excel("prices_round_1_day_0.xlsx")
#       2 trades = pd.read_csv("trades_round_1_day_0.csv")
#       3
#       4 print("Market data shape:", market.shape)
#
# File c:\Users\ksv27\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
# ...
